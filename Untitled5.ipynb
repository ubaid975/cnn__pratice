# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow import keras
from keras.layers import *

# %%
# !kaggle datasets download -d omkargurav/face-mask-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/omkargurav/face-mask-dataset
# License(s): unknown
# ...
# 100% 163M/163M [00:01<00:00, 191MB/s]
# 100% 163M/163M [00:01<00:00, 162MB/s]

# %%
import zipfile

# %%
z=zipfile.ZipFile('/content/face-mask-dataset.zip')

# %%
z.extractall()
z.close()

# %%
path='/content/data'

# %%
train_ds,val = keras.utils.image_dataset_from_directory(
  path,
  label_mode='int',
  labels = 'inferred',
  validation_split=0.2,
  subset="both",
  shuffle=True,
  seed=123,
  image_size=(254,254),
  batch_size=35)
# Out:
# Found 7553 files belonging to 2 classes.
# Using 6043 files for training.
# Using 1510 files for validation.

# %%
val
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 254, 254, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model=keras.Sequential()

# %%
model.add(Conv2D(64,(2,2),activation='relu',input_shape=(254,254,3),padding='same'))
model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D((2,2)))

# %%
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)                    │ (None, 254, 254, 64)        │             832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 254, 254, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 127, 127, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 127, 127, 64)        │          36,928 │
# ...

# %%
keras.utils.plot_model(model)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
model.fit(train_ds,epochs=100,validation_data=val,callbacks=[keras.callbacks.EarlyStopping()])
# Out:
# Epoch 1/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 46s 245ms/step - accuracy: 0.5662 - loss: 20.3498 - val_accuracy: 0.5947 - val_loss: 0.6671
# Epoch 2/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 81s 248ms/step - accuracy: 0.6505 - loss: 0.6315 - val_accuracy: 0.7099 - val_loss: 0.6430
# Epoch 3/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 82s 248ms/step - accuracy: 0.7389 - loss: 0.5430 - val_accuracy: 0.6775 - val_loss: 0.6623

# %%
test='/content/th (5).jpeg'

# %%
img_test=cv2.imread(test)

# %%
resize=cv2.resize(img_test,(254,254))

# %%
pred=model.predict(resize.reshape(1,254,254,3))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
np.where(pred>0.5,'mask','no mask')
# Out:
# array([['no mask']], dtype='<U7')

# %%
resize
# Out:
# array([[[150, 150, 156],
#         [145, 145, 151],
#         [142, 142, 148],
#         ...,
#         [ 76,  93,  79],
#         [ 77,  94,  80],
#         [ 80,  96,  83]],
#
#        [[146, 146, 152],
#         [141, 141, 146],
#         [137, 137, 143],
#         ...,
#         [ 75,  92,  78],
#         [ 76,  93,  79],
#         [ 78,  95,  81]],
#
#        [[143, 143, 149],
#         [137, 137, 143],
#         [134, 134, 140],
#         ...,
#         [ 74,  91,  77],
#         [ 73,  91,  76],
#         [ 76,  93,  79]],
#
#        ...,
#
#        [[145, 184, 147],
#         [143, 184, 147],
#         [144, 183, 147],
#         ...,
#         [112, 129, 101],
#         [ 90, 107,  79],
#         [ 78,  96,  68]],
#
#        [[143, 185, 147],
#         [142, 184, 146],
#         [143, 184, 146],
#         ...,
#         [124, 142, 113],
#         [100, 118,  89],
#         [ 86, 104,  75]],
#
#        [[142, 186, 147],
#         [141, 185, 146],
#         [141, 185, 146],
# ...

# %%
pred
# Out:
# array([[0.2681214]], dtype=float32)
